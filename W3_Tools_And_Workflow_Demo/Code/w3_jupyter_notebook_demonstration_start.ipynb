# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ISAT-DrG/ISAT_420_S26_Shared/blob/main/W3_Tools_And_Workflow_Demo/Code/w3_jupyter_notebook_demonstration_start.ipynb)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read in the data 
df = pd.read_excel('../Raw_Data/Global_Carbon_Budget_2023v1.0.xlsx',
                   sheet_name='Global Carbon Budget',
                   skiprows=21, index_col= 'Year', 
                  usecols = 'A:H')

# location of data if using google colab
# https://github.com/ISAT-DrG/ISAT_420_S26_Shared/raw/refs/heads/main/W3_Tools_And_Workflow_Demo/Raw_Data/Global_Carbon_Budget_2023v1.0.xlsx

# %%
# Data Processing 
df['ocean sink']=df['ocean sink']*-1
df['land sink']=df['land sink']*-1
df['atmospheric growth']=df['atmospheric growth']*-1

df.head() # head displays the first few rows
# Out:
#       fossil emissions excluding carbonation  land-use change emissions  \
# Year
# 1959                                2.416665                   2.121527
# 1960                                2.561796                   1.864403
# 1961                                2.569428                   1.787483
# 1962                                2.660086                   1.657757
# 1963                                2.801869                   1.604057
#
#       atmospheric growth  ocean sink  land sink  cement carbonation sink  \
# Year
# 1959            -2.03904   -0.992420  -0.430359                 0.012542
# 1960            -1.50804   -0.936514  -1.252347                 0.013682
# 1961            -1.65672   -0.839509  -0.899620                 0.014548
# 1962            -1.18944   -0.923603  -1.293962                 0.015680
# 1963            -1.21068   -1.111698  -0.959732                 0.016653
#
#       budget imbalance
# Year
# 1959          1.063831
# 1960          0.715617
# 1961          0.946515
# 1962          0.895158
# 1963          1.107163

# %%
# Plot the data 
fig, ax = plt.subplots(2,1,figsize=(10, 6))

df[['fossil emissions excluding carbonation','land-use change emissions']].plot.area(
    stacked=True,ax=ax[0], ylabel='Gt/y', xlabel = 'Year (1959-2022)')
df[['ocean sink','land sink','atmospheric growth']].plot.area(
    stacked=True,ax=ax[1], ylabel='Gt/y', xlabel = 'Year (1959-2022)')

# Save our result
plt.savefig('../Results/Global_Carbon_Budget_2023.png')
